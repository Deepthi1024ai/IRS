# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepthi1024ai/IRS/blob/main/untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

sentences = [
    "python programming language",
    "machine learning models",
    "data science analysis",
    "football match today",
    "cricket players practice"
]

vec = TfidfVectorizer()
data = vec.fit_transform(sentences)


k = KMeans(n_clusters=2, random_state=42)
clusters = k.fit_predict(data)


print("Cluster Results:\n")
for i in range(len(sentences)):
    s = sentences[i]
    c = clusters[i]
    print("Sentence:", s)
    print("Cluster:", c)
    print()
# Out:
# Cluster Results:
#
# Sentence: python programming language
# Cluster: 0
#
# Sentence: machine learning models
# Cluster: 0
#
# Sentence: data science analysis
# Cluster: 0
#
# Sentence: football match today
# Cluster: 0
#
# Sentence: cricket players practice
# Cluster: 1

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


text_data = [
    "free ticket win",
    "good morning",
    "earn money online",
    "how are you",
    "claim your prize",
    "nice to meet you"
]
labels = [1, 0, 1, 0, 1, 0]

data = pd.DataFrame({"msg": text_data, "label": labels})
print("Dataset used:")
print(data)


vector = CountVectorizer()
X = vector.fit_transform(data["msg"])
y = data["label"]

lr = LogisticRegression()
lr.fit(X, y)

test = ["win free ticket"]
test_vec = vector.transform(test)
prediction = lr.predict(test_vec)

print("\nTesting Message:", test[0])
if prediction[0] == 1:
    print("Prediction: spam message")
else:
    print("Prediction: normal message")
# Out:
# Dataset used:
#                  msg  label
# 0    free ticket win      1
# 1       good morning      0
# 2  earn money online      1
# 3        how are you      0
# 4   claim your prize      1
# 5   nice to meet you      0
#
# Testing Message: win free ticket
# Prediction: spam message
